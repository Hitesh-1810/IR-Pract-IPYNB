# %%
#  Stop word removal and Stemming on Text

import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
nltk.download("punkt") 
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
# stopwords removal in sample piece of text

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
data = "India is emerging as a global leader in Information Technology and Artificial Intelligence"

stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(data)

print(word_tokens)
# Out:
# ['India', 'is', 'emerging', 'as', 'a', 'global', 'leader', 'in', 'Information', 'Technology', 'and', 'Artificial', 'Intelligence']

# %%
# filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words] - list comprehension
filtered_sentence = []
for w in word_tokens:
    if w.lower() not in stop_words:
        filtered_sentence.append(w)

print(f"Case insensitive stop word removal : \n {filtered_sentence}")
# Out:
# Case insensitive stop word removal :
#  ['India', 'emerging', 'global', 'leader', 'Information', 'Technology', 'Artificial', 'Intelligence']

# %%
# Step 3: Apply Stemming
ps = PorterStemmer()
stemmed_words = []

for w in filtered_sentence:
    stemmed_words.append(ps.stem(w))

# %%
print(" STEMMING RESULT : ")
print("\n")
print("Original sentence: \n", data)
print("\n")
print("Stemming Result On Original Sentence After Stop Word Operation: \n", stemmed_words)
# Out:
#  STEMMING RESULT :
#
#
# Original sentence:
#  India is emerging as a global leader in Information Technology and Artificial Intelligence
#
#
# Stemming Result On Original Sentence After Stop Word Operation:
#  ['india', 'emerg', 'global', 'leader', 'inform', 'technolog', 'artifici', 'intellig']
