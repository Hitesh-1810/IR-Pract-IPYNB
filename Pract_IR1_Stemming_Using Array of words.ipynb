# %%
# stop word removal and stemming on Array of words

# %%
import nltk
nltk.download("punkt")
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Hitesh
# [nltk_data]     Girase\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
ps = PorterStemmer()

# %%
sample = ['program', 'programmer', 'programming', 'programs', 'programmers']

for s in sample:
    print(f"{s} : {ps.stem(s)}")
# Out:
# program : program
# programmer : programm
# programming : program
# programs : program
# programmers : programm

# %%
sentence = "Programmers program with different programming languages"
words = word_tokenize(sentence)
print(words)
# Out:
# ['Programmers', 'program', 'with', 'different', 'programming', 'languages']

# %%
for w in words:
    print(f"{w} : {ps.stem(w)}")
# Out:
# Programmers : programm
# program : program
# with : with
# different : differ
# programming : program
# languages : languag
